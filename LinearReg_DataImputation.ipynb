# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
from sklearn import svm
from mpl_toolkits.mplot3d import axes3d, Axes3D
import pandas as pd

# %%
data = pd.read_csv('LinearReg_Testfile.csv')
data.plot()
print(len(data))
# Out:
# 360

# %%
# Check correlation among variables

corr = data.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\berna\AppData\Local\Temp\ipykernel_1092\89182141.py:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_508f9_row0_col0, #T_508f9_row1_col1, #T_508f9_row2_col2, #T_508f9_row3_col3, #T_508f9_row4_col4, #T_508f9_row5_col5, #T_508f9_row6_col6, #T_508f9_row7_col7, #T_508f9_row8_col8, #T_508f9_row9_col9, #T_508f9_row10_col10, #T_508f9_row11_col11, #T_508f9_row12_col12, #T_508f9_row13_col13, #T_508f9_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col1, #T_508f9_row1_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_508f9_row0_col3, #T_508f9_row3_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col4, #T_508f9_row12_col13 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_508f9_row0_col5, #T_508f9_row2_col5, #T_508f9_row5_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col6 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col7, #T_508f9_row1_col7, #T_508f9_row7_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col9 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_508f9_row0_col10 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_508f9_row0_col11 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_508f9_row0_col12 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_508f9_row0_col13, #T_508f9_row4_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_508f9_row0_col14 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_508f9_row1_col2, #T_508f9_row1_col9 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_508f9_row1_col3, #T_508f9_row3_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_508f9_row1_col4, #T_508f9_row7_col10 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_508f9_row1_col5, #T_508f9_row5_col12, #T_508f9_row6_col1, #T_508f9_row13_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_508f9_row1_col6, #T_508f9_row12_col10 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_508f9_row1_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_508f9_row1_col10, #T_508f9_row7_col11, #T_508f9_row8_col12, #T_508f9_row11_col13 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_508f9_row1_col11, #T_508f9_row11_col6 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_508f9_row1_col12 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_508f9_row1_col13, #T_508f9_row4_col9, #T_508f9_row9_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_508f9_row1_col14 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_508f9_row2_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_508f9_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_508f9_row2_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_508f9_row2_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_508f9_row2_col6, #T_508f9_row6_col12 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_508f9_row2_col7, #T_508f9_row8_col13 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_508f9_row2_col8, #T_508f9_row4_col14, #T_508f9_row10_col14 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_508f9_row2_col9 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_508f9_row2_col10 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_508f9_row2_col11, #T_508f9_row3_col12, #T_508f9_row10_col11 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_508f9_row2_col12 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_508f9_row2_col13 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_508f9_row2_col14 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_508f9_row3_col2 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_508f9_row3_col4, #T_508f9_row4_col2, #T_508f9_row11_col3 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_508f9_row3_col5, #T_508f9_row5_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_508f9_row3_col6, #T_508f9_row10_col12, #T_508f9_row12_col11 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_508f9_row3_col7, #T_508f9_row6_col14 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_508f9_row3_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_508f9_row3_col9, #T_508f9_row3_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_508f9_row3_col10, #T_508f9_row11_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_508f9_row3_col13, #T_508f9_row7_col6, #T_508f9_row9_col2, #T_508f9_row9_col4, #T_508f9_row9_col5, #T_508f9_row9_col7, #T_508f9_row9_col10, #T_508f9_row9_col11, #T_508f9_row9_col12, #T_508f9_row12_col8, #T_508f9_row12_col9, #T_508f9_row12_col14, #T_508f9_row13_col0, #T_508f9_row13_col1, #T_508f9_row13_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_508f9_row3_col14 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_508f9_row4_col0, #T_508f9_row4_col3, #T_508f9_row14_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_508f9_row4_col1, #T_508f9_row8_col2, #T_508f9_row13_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_508f9_row4_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_508f9_row4_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_508f9_row4_col7, #T_508f9_row6_col11, #T_508f9_row10_col5 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_508f9_row4_col10, #T_508f9_row7_col4, #T_508f9_row13_col7 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_508f9_row4_col11 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_508f9_row4_col12 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_508f9_row4_col13 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_508f9_row5_col0, #T_508f9_row6_col3 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_508f9_row5_col1 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_508f9_row5_col4 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_508f9_row5_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_508f9_row5_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_508f9_row5_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_508f9_row5_col9, #T_508f9_row13_col14 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_508f9_row5_col10 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_508f9_row5_col11, #T_508f9_row10_col2, #T_508f9_row14_col9 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_508f9_row5_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_508f9_row5_col14 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_508f9_row6_col0, #T_508f9_row11_col12 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_508f9_row6_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_508f9_row6_col4 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_508f9_row6_col5 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_508f9_row6_col7, #T_508f9_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_508f9_row6_col8 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_508f9_row6_col9, #T_508f9_row10_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_508f9_row6_col10, #T_508f9_row11_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_508f9_row6_col13 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_508f9_row7_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_508f9_row7_col2, #T_508f9_row9_col8, #T_508f9_row11_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_508f9_row7_col5, #T_508f9_row8_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_508f9_row7_col8 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_508f9_row7_col9 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_508f9_row7_col12 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_508f9_row7_col13 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_508f9_row7_col14, #T_508f9_row10_col1, #T_508f9_row11_col7, #T_508f9_row14_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_508f9_row8_col0, #T_508f9_row14_col10 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_508f9_row8_col1, #T_508f9_row8_col3, #T_508f9_row13_col8, #T_50

# %%
# Cleaning data
data.drop('RAINF', axis=1)
# Out:
#        CO    NO   NO2   NOX    O3   PM10  PM2.5    PRS    RH  SO2   SR   TOUT  \
# 0    2.50   8.8  13.1  21.9  17.0   60.0    NaN  726.1  96.0  2.9  0.0   4.11
# 1    2.51  10.2  12.9  23.1  10.0  139.0   80.0  725.4  96.0  2.3  0.0   3.91
# 2    2.41   9.2  11.6  20.8   7.0   42.0   29.0  725.0  96.0  2.2  0.0   3.81
# 3    2.39   8.1  11.8  19.9   7.0   23.0    9.0  724.4  96.0  2.1  0.0   3.85
# 4    2.37   6.7  11.1  17.8   7.0   21.0    NaN  724.1  96.0  2.2  0.0   3.91
# ..    ...   ...   ...   ...   ...    ...    ...    ...   ...  ...  ...    ...
# 355  3.03  25.0  31.7  56.7   5.0  117.0   28.0  728.1  72.0  2.5  0.0  10.21
# 356  3.13  21.7  32.5  54.2   6.0  101.0   17.0  728.5  72.0  3.1  0.0   9.93
# 357  3.15  34.7  34.6  69.3   5.0  104.0   31.0  728.6  71.0  5.1  0.0   9.81
# 358  3.01  35.9  33.9  69.8   5.0   91.0   20.0  728.6  73.0  3.4  0.0   9.56
# 359  2.97  35.6  33.4  69.0   4.0   95.0   15.0  728.7  75.0  2.9  0.0   9.09
#
#      WSR    WDV
# 0    8.1  350.0
# 1    7.2  344.0
# 2    6.3  341.0
# 3    5.2  346.0
# 4    4.8  356.0
# ..   ...    ...
# 355  3.5   35.0
# 356  3.6    8.0
# 357  3.0  321.0
# 358  3.5  322.0
# 359  3.5  325.0
#
# [360 rows x 14 columns]

# %%
# for x in data:
    # print(data[x].isnull())
# dnull = data.isnull()
# for x in dnull:
#     count = 0
#     # for y in dnull[x]:
#     #     # if (dnull[x][y] == True):
#     #     # print(dnull[x].loc[y])
#     #     # print(y)
#     #     count += 1
#     print('%s null count: %i' %dnull[x].name, count)
